# %%
import pandas as pd #(version 0.24.2)
import datetime as dt
import os
import plotly       #(version 4.4.1)
import plotly.express as px

# %%
filename = 'data/Urban_Park_Ranger_Animal_Condition_Response.csv'
df = pd.read_csv(filename)
df
# Out:
#     Date and Time of initial call Date and time of Ranger response  \
# 0                  11/9/2018 9:00                  11/9/2018 10:15
# 1                11/30/2018 11:00                 11/30/2018 13:45
# 2                11/10/2018 15:00                 11/10/2018 15:10
# 3                  9/4/2018 14:30                   9/4/2018 15:50
# 4                   6/9/2019 9:30                   6/9/2019 10:00
# ..                            ...                              ...
# 977               2/20/2019 18:40                  2/21/2019 12:00
# 978                1/8/2019 14:32                    1/8/2019 9:45
# 979               7/29/2018 13:00                  7/30/2018 13:30
# 980                5/7/2018 13:30                   5/7/2018 13:40
# 981                 5/2/2018 9:30                   5/2/2018 12:00
#
#            Borough                                     Property  \
# 0         Brooklyn                               Bushwick Inlet
# 1        Manhattan                             Inwood Hill Park
# 2        Manhattan                             Inwood Hill Park
# 3    Staten Island  Ocean Breeze Track & Field Athletic Complex
# 4         Brooklyn                                Parade Ground
# ..             ...                                          ...
# 977  Staten Island                              Industrial Park
# 978  Staten Island                            Joseph Manna Park
# 979       Brooklyn                                McCarren Park
# 980      Manhattan                                 Central Park
# 981      Manhattan                                 Central Park
#
#                                             Location    Species Description  \
# 0                                Bushwick Inlet Park  Chinese Silky Chicken
# 1                               M & O HQ District 12                Chicken
# 2                                 Dykman Ball Fields                Chicken
# 3                       Father Capodanno and Seaview              Rock Dove
# 4    Prospect Park Parade Grounds near Tennis Center                Chicken
# ..                                               ...                    ...
# 977        In small patch of woods along Graham Ave.                   Deer
# 978                                    Shrub in Park                   Deer
# 979                                              NaN        Red Tailed Hawk
# 980                                              NaN        Red Tailed Hawk
# 981                                              NaN                raccoon
#
#     Call Source Species Status Animal Condition  Duration of Response  ...  \
# 0      Employee         Exotic          Healthy                  1.25  ...
# 1      Employee       Domestic          Healthy                  1.00  ...
# 2      Employee       Domestic          Healthy                  1.50  ...
# 3      Employee         Native          Healthy                  2.50  ...
# 4       Central       Domestic          Healthy                  3.00  ...
# ..          ...            ...              ...                   ...  ...
# 977       Other         Native          Healthy                  1.00  ...
# 978     Central         Native          Healthy                  0.25  ...
# 979    Employee         Native          Healthy                  0.50  ...
# 980    Employee         Native  Dead on arrival                  1.00  ...
# 981      Public         Native          Healthy                  0.75  ...
#
#        311SR Number        Final Ranger Action # of Animals PEP Response  \
# 0    1-1-1642034010         Animal Care Center          1.0        False
# 1    1-1-1647471950         Animal Care Center          1.0        False
# 2    1-1-1642034151         Animal Care Center          1.0        False
# 3    1-1-1613258011         Animal Care Center          1.0         True
# 4    1-1-1730643971         Animal Care Center          1.0        False
# ..              ...                        ...          ...          ...
# 977             NaN                  Unfounded          1.0        False
# 978             NaN                  Unfounded          1.0        False
# 979             NaN           Monitored Animal          3.0        False
# 980             NaN  Submitted for DEC Testing          1.0          NaN
# 981             NaN                  Unfounded          1.0          NaN
#
#      Animal Monitored Rehabilitator  Hours spent monitoring Police Response  \
# 0               False           NaN                     NaN           False
# 1               False           NaN                     NaN           False
# 2               False           NaN                     NaN           False
# 3               False           NaN                     NaN           False
# 4               False           NaN                     NaN           False
# ..                ...           ...                     ...             ...
# 977              True           NaN                    0.50           False
# 978              True           NaN                    0.25           False
# 979              True           NaN                    0.50           False
# 980              True           NaN                     NaN             NaN
# 981              True           NaN                     NaN             NaN
#
#      ESU Response ACC Intake Number
# 0           False             46854
# 1           False             48438
# 2           False             46961
# 3           False             40608
# 4           False             65352
# ..            ...               ...
# 977         False               NaN
# 978         False               NaN
# 979         False               NaN
# 980         False               NaN
# 981         False               NaN
#
# [982 rows x 22 columns]

# %%
df = df[(df['# of Animals']>0) & (df['Age']!='Multiple')]

# %%
# Extract month from time call made to Ranger
df['Month of Initial Call'] = pd.to_datetime(df['Date and Time of initial call'])
df['Month of Initial Call'] = df['Month of Initial Call'].dt.strftime('%m')
# Out:
# /Users/jiangchang/Desktop/Github/dash_learning/venv/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/jiangchang/Desktop/Github/dash_learning/venv/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Copy columns to new columns with clearer names
df['Amount of Animals'] = df['# of Animals']
df['Time Spent on Site (hours)'] = df['Duration of Response']
# Out:
# /Users/jiangchang/Desktop/Github/dash_learning/venv/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/jiangchang/Desktop/Github/dash_learning/venv/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df
# Out:
#     Date and Time of initial call Date and time of Ranger response  \
# 0                  11/9/2018 9:00                  11/9/2018 10:15
# 1                11/30/2018 11:00                 11/30/2018 13:45
# 2                11/10/2018 15:00                 11/10/2018 15:10
# 3                  9/4/2018 14:30                   9/4/2018 15:50
# 4                   6/9/2019 9:30                   6/9/2019 10:00
# ..                            ...                              ...
# 976               7/12/2018 15:00                  7/12/2018 15:25
# 977               2/20/2019 18:40                  2/21/2019 12:00
# 978                1/8/2019 14:32                    1/8/2019 9:45
# 980                5/7/2018 13:30                   5/7/2018 13:40
# 981                 5/2/2018 9:30                   5/2/2018 12:00
#
#            Borough                                     Property  \
# 0         Brooklyn                               Bushwick Inlet
# 1        Manhattan                             Inwood Hill Park
# 2        Manhattan                             Inwood Hill Park
# 3    Staten Island  Ocean Breeze Track & Field Athletic Complex
# 4         Brooklyn                                Parade Ground
# ..             ...                                          ...
# 976      Manhattan                                 Central Park
# 977  Staten Island                              Industrial Park
# 978  Staten Island                            Joseph Manna Park
# 980      Manhattan                                 Central Park
# 981      Manhattan                                 Central Park
#
#                                             Location    Species Description  \
# 0                                Bushwick Inlet Park  Chinese Silky Chicken
# 1                               M & O HQ District 12                Chicken
# 2                                 Dykman Ball Fields                Chicken
# 3                       Father Capodanno and Seaview              Rock Dove
# 4    Prospect Park Parade Grounds near Tennis Center                Chicken
# ..                                               ...                    ...
# 976                                     Sheep Meadow                Raccoon
# 977        In small patch of woods along Graham Ave.                   Deer
# 978                                    Shrub in Park                   Deer
# 980                                              NaN        Red Tailed Hawk
# 981                                              NaN                raccoon
#
#                            Call Source Species Status Animal Condition  \
# 0                             Employee         Exotic          Healthy
# 1                             Employee       Domestic          Healthy
# 2                             Employee       Domestic          Healthy
# 3                             Employee         Native          Healthy
# 4                              Central       Domestic          Healthy
# ..                                 ...            ...              ...
# 976  Conservancies/"Friends of" Groups         Native          Healthy
# 977                              Other         Native          Healthy
# 978                            Central         Native          Healthy
# 980                           Employee         Native  Dead on arrival
# 981                             Public         Native          Healthy
#
#      Duration of Response  ... PEP Response Animal Monitored Rehabilitator  \
# 0                    1.25  ...        False            False           NaN
# 1                    1.00  ...        False            False           NaN
# 2                    1.50  ...        False            False           NaN
# 3                    2.50  ...         True            False           NaN
# 4                    3.00  ...        False            False           NaN
# ..                    ...  ...          ...              ...           ...
# 976                  1.00  ...        False             True           NaN
# 977                  1.00  ...        False             True           NaN
# 978                  0.25  ...        False             True           NaN
# 980                  1.00  ...          NaN             True           NaN
# 981                  0.75  ...          NaN             True           NaN
#
#     Hours spent monitoring  Police Response ESU Response  ACC Intake Number  \
# 0                      NaN            False        False              46854
# 1                      NaN            False        False              48438
# 2                      NaN            False        False              46961
# 3                      NaN            False        False              40608
# 4                      NaN            False        False              65352
# ..                     ...              ...          ...                ...
# 976                   1.00            False        False                NaN
# 977                   0.50            False        False                NaN
# 978                   0.25            False        False                NaN
# 980                    NaN              NaN        False                NaN
# 981                    NaN              NaN        False                NaN
#
#     Month of Initial Call  Amount of Animals Time Spent on Site (hours)
# 0                      11                1.0                       1.25
# 1                      11                1.0                       1.00
# 2                      11                1.0                       1.50
# 3                      09                1.0                       2.50
# 4                      06                1.0                       3.00
# ..                    ...                ...                        ...
# 976                    07                1.0                       1.00
# 977                    02                1.0                       1.00
# 978                    01                1.0                       0.25
# 980                    05                1.0                       1.00
# 981                    05                1.0                       0.75
#
# [930 rows x 25 columns]

# %%
a = [1,3,3,3,4,4,6,7,7,7]

# %%
table = {}
for i in range(min(a), max(a)):
    table[i] = sum([i == x for x in a])
table
# Out:
# {1: 1, 2: 0, 3: 3, 4: 2, 5: 0, 6: 1}

# %%
sum([i == 3 for i in a])
# Out:
# 3

# %%
aa = list(table.values())
aa
# Out:
# [1, 0, 3, 2, 0, 1]
